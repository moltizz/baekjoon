# %% [markdown]
# # 나머지

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a, b, c = map(int, input().split())

if 2 <= a and b and c <= 10000:
    print((a+b)%c)
    print(((a%c)+(b%c))%c)
    print((a*b)%c)
    print(((a%c)*(b%c))%c)
# Out:
# 5 8 4
# 1
# 1
# 0
# 0
