# %% [markdown]
# # 더하기 사이클

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###구글링 정답

# %%
n = int(input())            # 68
num = n
cnt = 0                     # 사이클 수

while True:                 # while 1이랑 동일
    a = num // 10           # 6
    b = num % 10            # 8
    c = (a + b) % 10        # 6 + 8 = 1"4"
    num = (b * 10) + c      # 80 + 4 = 84

    cnt += 1                # 사이클 수 + 1
    if(num == n):           # num에서 입력된 n과 똑같은 숫자(68)가 나오면 멈춤
        break

print(cnt)
# Out:
# 68
# 4

# %% [markdown]
# 사칙연산을 사용하는 아이디어를 생각하지 못했었다. 또한, while문 안에 if문을 어떤 식으로 넣어야 할 지 감이 잡히지 않았다. 결국, 구글링의 도움을 받았다.

# %% [markdown]
# ### 시도

# %%
# 막연히 생각해본 코드
a, b = map(int, input())

if a == 0 and b < 9:
  print(0b)

while True:
    a+b
    b,a+b

# %% [markdown]
# **✍ 회고**

# %% [markdown]
# * 어떻게 보면 당연한 건데, 사칙연산을 사용할 생각을 하지 못했다. 조금 더 생각해보면 접근할 수 있었을 법한데... 단편적인 사고로 문제에 접근했다.

# %% [markdown]
# * while문 안에 if문을 어떤 식으로 쓰는지 감이 안잡혔다. 처음엔 전체적으로 각 범위마다 if문을 써야 될 것이라 생각했다. 하지만 구글링 정답을 보면, 마지막에 break 걸어줄 때만 사용한 것을 볼 수 있다.

# %% [markdown]
# * 코드에 주석을 달지 않았었는데, 다른 분들의 코드를 참고하면서 느낀 바로 코드에 주석을 달아야겠다. 이 과정이 코드를 이해하는데 도움을 줄 것이고, 더욱 직관적인 이해를 도울 것이다.

# %% [markdown]
# **⭐ 참고자료**

# %% [markdown]
# * https://wook-2124.tistory.com/222  (다양한 시도)

# %% [markdown]
# * https://sso-feeling.tistory.com/371  (친절한 설명)
