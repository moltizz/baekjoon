# %% [markdown]
# # 고양이

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("\    /\")
print(" )  ( ')")
print("(  /  )")
print(" \(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|
