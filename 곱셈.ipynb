# %% [markdown]
# # 곱셈

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a, b, c = map(int, input())
d, e, f = map(int, input())

x1 = (a*100+b*10+c)*f
x2 = (a*100+b*10+c)*e*10
x3 =(a*100+b*10+c)*d*100

print(x1)
print(round(x2/10))
print(round(x3/100))
print(x1+x2+x3)
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720
