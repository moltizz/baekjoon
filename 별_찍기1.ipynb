# %% [markdown]
# # 별 찍기 - 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###성공

# %%
t = int(input())

for i in range(t):
  i+=1
  print('*'*i)
# Out:
# 5
# *
# **
# ***
# ****
# *****

# %% [markdown]
# **✍ 회고**

# %% [markdown]
# 이번엔 구글링 없이 혼자 힘으로 해냈다! 예전에 이 문제를 봤을 땐 풀지 못 했었는데, 성공해서 성장하고 있음을 느낀다. 적자마자 바로 시도한 것은 아니고 조금씩 답으로 유도해나갔다. 문제의 원리를 이해한 것이 전체적으로 도움이 되었다.
